# %%
import pandas as pd
import numpy as np
from matplotlib import pylab as plt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.model_selection import StratifiedKFold

# %%
airbnb = pd.read_csv(r'AB_NYC_2019.csv')#load the airbnb dataset
airbnb.drop("id", axis=1, inplace=True )
print(airbnb.shape[0])
print(airbnb.shape[1])
airbnb.describe(include="all")
# Out:
# 48895
# 15
#                   name       host_id host_name neighbourhood_group  \
# count            48879  4.889500e+04     48874               48895
# unique           47905           NaN     11452                   5
# top     Hillside Hotel           NaN   Michael           Manhattan
# freq                18           NaN       417               21661
# mean               NaN  6.762001e+07       NaN                 NaN
# std                NaN  7.861097e+07       NaN                 NaN
# min                NaN  2.438000e+03       NaN                 NaN
# 25%                NaN  7.822033e+06       NaN                 NaN
# 50%                NaN  3.079382e+07       NaN                 NaN
# 75%                NaN  1.074344e+08       NaN                 NaN
# max                NaN  2.743213e+08       NaN                 NaN
#
#        neighbourhood      latitude     longitude        room_type  \
# count          48895  48895.000000  48895.000000            48895
# unique           221           NaN           NaN                3
# top     Williamsburg           NaN           NaN  Entire home/apt
# freq            3920           NaN           NaN            25409
# mean             NaN     40.728949    -73.952170              NaN
# std              NaN      0.054530      0.046157              NaN
# min              NaN     40.499790    -74.244420              NaN
# 25%              NaN     40.690100    -73.983070              NaN
# 50%              NaN     40.723070    -73.955680              NaN
# 75%              NaN     40.763115    -73.936275              NaN
# max              NaN     40.913060    -73.712990              NaN
#
#                price  minimum_nights  number_of_reviews last_review  \
# count   48895.000000    48895.000000       48895.000000       38843
# unique           NaN             NaN                NaN        1764
# top              NaN             NaN                NaN  2019-06-23
# freq             NaN             NaN                NaN        1413
# mean      152.720687        7.029962          23.274466         NaN
# std       240.154170       20.510550          44.550582         NaN
# min         0.000000        1.000000           0.000000         NaN
# 25%        69.000000        1.000000           1.000000         NaN
# 50%       106.000000        3.000000           5.000000         NaN
# 75%       175.000000        5.000000          24.000000         NaN
# max     10000.000000     1250.000000         629.000000         NaN
#
#         reviews_per_month  calculated_host_listings_count  availability_365
# count        38843.000000                    48895.000000      48895.000000
# unique                NaN                             NaN               NaN
# top                   NaN                             NaN               NaN
# freq                  NaN                             NaN               NaN
# mean             1.373221                        7.143982        112.781327
# std              1.680442                       32.952519        131.622289
# min              0.010000                        1.000000          0.000000
# 25%              0.190000                        1.000000          0.000000
# 50%              0.720000                        1.000000         45.000000
# 75%              2.020000                        2.000000        227.000000
# max             58.500000                      327.000000        365.000000

# %%
airbnb.head()
# Out:
#                                                name  host_id    host_name  \
# 0                Clean & quiet apt home by the park     2787         John
# 1                             Skylit Midtown Castle     2845     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
# 3     89               1                270  2019-07-05               4.64
# 4     80              10                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
airbnb.duplicated().sum()
airbnb.drop_duplicates(inplace=True)#remove duplicates

# %%
#find the percentage of missing values 
print('data dimensions:',airbnb.shape)
perc_missing_per_ftr = airbnb.isnull().sum(axis=0)/airbnb.shape[0]
print(perc_missing_per_ftr)
print('fraction of missing values in features:')
print(perc_missing_per_ftr[perc_missing_per_ftr > 0])
print('data types of the features with missing values:')
print(airbnb[perc_missing_per_ftr[perc_missing_per_ftr > 0].index].dtypes)
frac_missing = sum(airbnb.isnull().sum(axis=1)!=0)/airbnb.shape[0]
print('fraction of points with missing values:',frac_missing)
# Out:
# data dimensions: (48895, 15)
# name                              0.000327
# host_id                           0.000000
# host_name                         0.000429
# neighbourhood_group               0.000000
# neighbourhood                     0.000000
# latitude                          0.000000
# longitude                         0.000000
# room_type                         0.000000
# price                             0.000000
# minimum_nights                    0.000000
# number_of_reviews                 0.000000
# last_review                       0.205583
# reviews_per_month                 0.205583
# calculated_host_listings_count    0.000000
# availability_365                  0.000000
# dtype: float64
# fraction of missing values in features:
# name                 0.000327
# host_name            0.000429
# last_review          0.205583
# reviews_per_month    0.205583
# dtype: float64
# data types of the features with missing values:
# name                  object
# host_name             object
# last_review           object
# reviews_per_month    float64
# dtype: object
# fraction of points with missing values: 0.20603333674199817

# %%
j = 0
for col in airbnb.columns:
    j += 1
    print(j, "Column:", col, " ---> Type: ", airbnb[col].dtypes)
#data types of each column
# Out:
# 1 Column: name  ---> Type:  object
# 2 Column: host_id  ---> Type:  int64
# 3 Column: host_name  ---> Type:  object
# 4 Column: neighbourhood_group  ---> Type:  object
# 5 Column: neighbourhood  ---> Type:  object
# 6 Column: latitude  ---> Type:  float64
# 7 Column: longitude  ---> Type:  float64
# 8 Column: room_type  ---> Type:  object
# 9 Column: price  ---> Type:  int64
# 10 Column: minimum_nights  ---> Type:  int64
# 11 Column: number_of_reviews  ---> Type:  int64
# 12 Column: last_review  ---> Type:  object
# 13 Column: reviews_per_month  ---> Type:  float64
# 14 Column: calculated_host_listings_count  ---> Type:  int64
# 15 Column: availability_365  ---> Type:  int64

# %%
j = 0
#Description of each column including number of unique elements, frequency and count  
for col in airbnb.columns:
    j += 1
    res_col1 = airbnb[col].describe()
    res_col2 = airbnb[col].value_counts()
    print(j, "Describe the column: \n", res_col1)
    print("-------------------------------------\n")
    print("Value counts of the column: \n", res_col2)
    print("------------------------------------\n")
# Out:
# 1 Describe the column:
#  count              48879
# unique             47905
# top       Hillside Hotel
# freq                  18
# Name: name, dtype: object
# -------------------------------------
#
# Value counts of the column:
#  Hillside Hotel                                        18
# Home away from home                                   17
# New york Multi-unit building                          16
# Brooklyn Apartment                                    12
# Loft Suite @ The Box House Hotel                      11
#                                                       ..
# Large 1BR Apt. in Williamsburg                         1
# Feel at Home                                           1
# Spacious Modern Alcove Studio in a Luxury Building     1
# Artist's Room in Large Apartment                       1
# Trendy duplex in the very heart of Hell's Kitchen      1
# Name: name, Length: 47905, dtype: int64
# ------------------------------------
#
# 2 Describe the column:
#  count    4.889500e+04
# mean     6.762001e+07
# std      7.861097e+07
# min      2.438000e+03
# 25%      7.822033e+06
# 50%      3.079382e+07
# 75%      1.074344e+08
# max      2.743213e+08
# Name: host_id, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64
# ------------------------------------
#
# 3 Describe the column:
#  count       48874
# unique      11452
# top       Michael
# freq          417
# Name: host_name, dtype: object
# -------------------------------------
#
# Value counts of the column:
#  Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: host_name, Length: 11452, dtype: int64
# ------------------------------------
#
# 4 Describe the column:
#  count         48895
# unique            5
# top       Manhattan
# freq          21661
# Name: neighbourhood_group, dtype: object
# -------------------------------------
#
# Value counts of the column:
#  Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64
# ------------------------------------
#
# 5 Describe the column:
#  count            48895
# unique             221
# top       Williamsburg
# freq              3920
# Name: neighbourhood, dtype: object
# -------------------------------------
#
# Value counts of the column:
#  Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: neighbourhood, Length: 221, dtype: int64
# ------------------------------------
#
# 6 Describe the column:
#  count    48895.000000
# mean        40.728949
# std          0.054530
# min         40.499790
# 25%         40.690100
# 50%         40.723070
# 75%         40.763115
# max         40.913060
# Name: latitude, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  40.71813    18
# 40.68444    13
# 40.69414    13
# 40.68634    13
# 40.76125    12
#             ..
# 40.78084     1
# 40.66767     1
# 40.77473     1
# 40.79343     1
# 40.81475     1
# Name: latitude, Length: 19048, dtype: int64
# ------------------------------------
#
# 7 Describe the column:
#  count    48895.000000
# mean       -73.952170
# std          0.046157
# min        -74.244420
# 25%        -73.983070
# 50%        -73.955680
# 75%        -73.936275
# max        -73.712990
# Name: longitude, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  -73.95677    18
# -73.95427    18
# -73.95405    17
# -73.95060    16
# -73.94791    16
#              ..
# -73.85155     1
# -73.83167     1
# -73.85058     1
# -73.79232     1
# -73.80844     1
# Name: longitude, Length: 14718, dtype: int64
# ------------------------------------
#
# 8 Describe the column:
#  count               48895
# unique                  3
# top       Entire home/apt
# freq                25409
# Name: room_type, dtype: object
# -------------------------------------
#
# Value counts of the column:
#  Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64
# ------------------------------------
#
# 9 Describe the column:
#  count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  100    2051
# 150    2047
# 50     1534
# 60     1458
# 200    1401
#        ...
# 780       1
# 386       1
# 888       1
# 483       1
# 338       1
# Name: price, Length: 674, dtype: int64
# ------------------------------------
#
# 10 Describe the column:
#  count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  1      12720
# 2      11696
# 3       7999
# 30      3760
# 4       3303
#        ...
# 186        1
# 366        1
# 68         1
# 87         1
# 36         1
# Name: minimum_nights, Length: 109, dtype: int64
# ------------------------------------
#
# 11 Describe the column:
#  count    48895.000000
# mean        23.274466
# std         44.550582
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         24.000000
# max        629.000000
# Name: number_of_reviews, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  0      10052
# 1       5244
# 2       3465
# 3       2520
# 4       1994
#        ...
# 313        1
# 540        1
# 480        1
# 326        1
# 341        1
# Name: number_of_reviews, Length: 394, dtype: int64
# ------------------------------------
#
# 12 Describe the column:
#  count          38843
# unique          1764
# top       2019-06-23
# freq            1413
# Name: last_review, dtype: object
# -------------------------------------
#
# Value counts of the column:
#  2019-06-23    1413
# 2019-07-01    1359
# 2019-06-30    1341
# 2019-06-24     875
# 2019-07-07     718
#               ...
# 2012-12-25       1
# 2013-10-01       1
# 2014-05-29       1
# 2014-04-19       1
# 2018-03-29       1
# Name: last_review, Length: 1764, dtype: int64
# ------------------------------------
#
# 13 Describe the column:
#  count    38843.000000
# mean         1.373221
# std          1.680442
# min          0.010000
# 25%          0.190000
# 50%          0.720000
# 75%          2.020000
# max         58.500000
# Name: reviews_per_month, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  0.02     919
# 0.05     893
# 1.00     893
# 0.03     804
# 0.16     667
#         ...
# 9.53       1
# 9.74       1
# 6.06       1
# 8.25       1
# 10.54      1
# Name: reviews_per_month, Length: 937, dtype: int64
# ------------------------------------
#
# 14 Describe the column:
#  count    48895.000000
# mean         7.143982
# std         32.952519
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        327.000000
# Name: calculated_host_listings_count, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 25        50
# 50        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: calculated_host_listings_count, dtype: int64
# ------------------------------------
#
# 15 Describe the column:
#  count    48895.000000
# mean       112.781327
# std        131.622289
# min          0.000000
# 25%          0.000000
# 50%         45.000000
# 75%        227.000000
# max        365.000000
# Name: availability_365, dtype: float64
# -------------------------------------
#
# Value counts of the column:
#  0      17533
# 365     1295
# 364      491
# 1        408
# 89       361
#        ...
# 195       26
# 183       24
# 196       24
# 181       23
# 202       20
# Name: availability_365, Length: 366, dtype: int64
# ------------------------------------

# %%
airbnb.plot.scatter('price','number_of_reviews',alpha=0.3,s=10)
plt.title('price vs number_of_reviews')
plt.ylabel('number_of_reviews')
plt.plot()
plt.show()

# %%
airbnb.plot.scatter('price','reviews_per_month',alpha=0.3,s=10)
plt.title('price vs reviews_per_month')
plt.ylabel('reviews_per_month')
plt.plot()
plt.show()

# %%
airbnb.plot.scatter('price','calculated_host_listings_count',alpha=0.3,s=10)
plt.title('price vs calculated_host_listings_count')
plt.ylabel('calculated_host_listings_count')
plt.plot()
plt.show()

# %%
corr = airbnb.corr()#correlation heatmap
plt.figure(figsize=(8,8))
sns.heatmap(corr, annot=True)
airbnb.columns
# Out:
# Index(['name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
plt.figure(figsize=(8,8))
ax = sns.boxplot(data=airbnb, x='neighbourhood_group',y='number_of_reviews')

# %%
plt.figure(figsize=(8,8))
ax = sns.boxplot(data=airbnb, x='neighbourhood_group',y='availability_365')

# %%
count_matrix = airbnb.groupby(['neighbourhood_group', 'room_type']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('room_type_fraction')
plt.legend(loc=4)
plt.title("neighbourhood_group vs room_type")
plt.plot()
# Out:
# []

# %%
dataset = [airbnb[airbnb['room_type']=='Entire home/apt']['number_of_reviews'].values,
           airbnb[airbnb['room_type']=='Private room']['number_of_reviews'].values,
           airbnb[airbnb['room_type']=='Shared room']['number_of_reviews'].values]

plt.violinplot(dataset = dataset)
plt.xticks([1,2,3],['Entire home/apt','Private room','Shared room'])
plt.ylabel('number_of_reviews')
plt.xlabel('room_type')
plt.title("room_type vs number_of_reviews")
plt.plot()
# Out:
# []

# %%
#dropping of unwanted columns
airbnb.drop("name", axis=1, inplace=True)
airbnb.drop("host_name", axis=1, inplace=True)
airbnb.drop("host_id", axis=1, inplace=True)
airbnb.drop("last_review", axis=1, inplace=True)
# airbnb.dropna(axis=0, inplace=True)

# %%
#fraction of missing data after dropping of unwanted columns
print('data dimensions:',airbnb.shape)
perc_missing_per_ftr = airbnb.isnull().sum(axis=0)/airbnb.shape[0]
print(perc_missing_per_ftr)
print('fraction of missing values in features:')
print(perc_missing_per_ftr[perc_missing_per_ftr > 0])
print('data types of the features with missing values:')
print(airbnb[perc_missing_per_ftr[perc_missing_per_ftr > 0].index].dtypes)
frac_missing = sum(airbnb.isnull().sum(axis=1)!=0)/airbnb.shape[0]
print('fraction of points with missing values:',frac_missing)
# Out:
# data dimensions: (48895, 11)
# neighbourhood_group               0.000000
# neighbourhood                     0.000000
# latitude                          0.000000
# longitude                         0.000000
# room_type                         0.000000
# price                             0.000000
# minimum_nights                    0.000000
# number_of_reviews                 0.000000
# reviews_per_month                 0.205583
# calculated_host_listings_count    0.000000
# availability_365                  0.000000
# dtype: float64
# fraction of missing values in features:
# reviews_per_month    0.205583
# dtype: float64
# data types of the features with missing values:
# reviews_per_month    float64
# dtype: object
# fraction of points with missing values: 0.20558339298496778

# %%
airbnb.shape
# Out:
# (48895, 11)

# %%
y = airbnb["price"]
X = airbnb.loc[:, airbnb.columns!="price"]

# %%
print(y.shape)
print(X.shape)
# Out:
# (48895,)
# (48895, 10)

# %%
j = 0
for col in airbnb.columns:
    j += 1
    print(col)
# Out:
# neighbourhood_group
# neighbourhood
# latitude
# longitude
# room_type
# price
# minimum_nights
# number_of_reviews
# reviews_per_month
# calculated_host_listings_count
# availability_365

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

onehot_ftrs = ['neighbourhood_group', 'room_type', 'neighbourhood']
std_ftrs = ['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']

#preprocess the data using onehot encoder and standard scalar encoder for catergorical and continunous data respectively.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant',fill_value='missing')),
    ('onehot', OneHotEncoder(sparse=False,handle_unknown='ignore'))]) 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('std', StandardScaler())])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, std_ftrs),
        ('cat', categorical_transformer, onehot_ftrs)])

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
import math
from sklearn.metrics import make_scorer, r2_score
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


def MLpipe_KFold(X, y, preprocessor, ML_algo, param_grid):
#This def takes preprocessor,dataset, ML algorithm and parameters as input. Then uses GridSearchCV to select best parameters
#r2_score is used to evaluate the test data set. The grid with best parameters are returned along with the r2 scores.
    grid_lst = []
    bst_scores = []
    test_scores = []
    random_state = [2,4,10,15,28,35]#looping through 5 random states
    for i in random_state:
        X_other, X_test, y_other, y_test = train_test_split(X, y, test_size = 0.2, random_state=i)
        kf = KFold(n_splits=5)#split into 5 folds
        pipe = Pipeline(steps=[('preprocessor', preprocessor), ('ML_algo', ML_algo)])
        grid = GridSearchCV(pipe, param_grid=param_grid, scoring = make_scorer(r2_score) ,cv=kf, return_train_score = True, n_jobs=-1, verbose=True)
        grid.fit(X_other, y_other)
        y_pred = grid.predict(X_test)
        test_scores.append(r2_score(y_test, y_pred))
        grid_lst.append(grid.best_params_)
    return grid_lst, test_scores

# %%
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings("ignore")

#Lasso with parameters is used to train the model. Model with best parameters is selected. The mean of r2 score is calculated.
param_grid = {'ML_algo__alpha':[100.0, 35.938136638046274, 12.91549665014884, 4.641588833612779, 1.668100537200059, 0.5994842503189408, 0.21544346900318845, 0.07742636826811278, 0.027825594022071257, 0.01], 'ML_algo__max_iter':[100000000], 'ML_algo__random_state':[10]} 
model1, test_scores1 = MLpipe_KFold(X, y, preprocessor, Lasso(), param_grid)
print("-----------------------------")
for m in model1:
    print(m)
print("-----------------------------")
for s in test_scores1:
    print(s)
print("-----------------------------")
print('r2_score:',"mean",np.around(np.mean(test_scores1),3),'+/-',np.around(np.std(test_scores1),3),"standard deviation")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# -----------------------------
# {'ML_algo__alpha': 0.07742636826811278, 'ML_algo__max_iter': 100000000, 'ML_algo__random_state': 10}
# {'ML_algo__alpha': 0.07742636826811278, 'ML_algo__max_iter': 100000000, 'ML_algo__random_state': 10}
# {'ML_algo__alpha': 0.07742636826811278, 'ML_algo__max_iter': 100000000, 'ML_algo__random_state': 10}
# {'ML_algo__alpha': 0.07742636826811278, 'ML_algo__max_iter': 100000000, 'ML_algo__random_state': 10}
# {'ML_algo__alpha': 0.027825594022071257, 'ML_algo__max_iter': 100000000, 'ML_algo__random_state': 10}
# {'ML_algo__alpha': 0.07742636826811278, 'ML_algo__max_iter': 100000000, 'ML_algo__random_state': 10}
# -----------------------------
# 0.1268531976039512
# 0.15237091784590995
# 0.14864377358887226
# 0.09808984144811683
# 0.11684700515036572
# 0.10085316245169795
# -----------------------------
# r2_score: mean 0.124 +/- 0.021 standard deviation

# %%
from sklearn.linear_model import Ridge
#Ridge with parameters is used to train the model. Model with best parameters is selected. The mean of r2 score is calculated.

param_grid = {'ML_algo__alpha':[100.0, 35.938136638046274, 12.91549665014884, 4.641588833612779, 1.668100537200059, 0.5994842503189408, 0.21544346900318845, 0.07742636826811278, 0.027825594022071257, 0.01], 'ML_algo__solver':['saga'], 'ML_algo__random_state':[10]} 
model2, test_scores2 = MLpipe_KFold(X, y, preprocessor, Ridge(), param_grid)
print("-----------------------------")
for m in model2:
    print(m)
    
print("-----------------------------")
for s in test_scores2:
    print(s)
print("-----------------------------")
print('r2_score:',"mean",np.around(np.mean(test_scores2),3),'+/-',np.around(np.std(test_scores2),3),"standard deviation")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# -----------------------------
# {'ML_algo__alpha': 35.938136638046274, 'ML_algo__random_state': 10, 'ML_algo__solver': 'saga'}
# {'ML_algo__alpha': 35.938136638046274, 'ML_algo__random_state': 10, 'ML_algo__solver': 'saga'}
# {'ML_algo__alpha': 35.938136638046274, 'ML_algo__random_state': 10, 'ML_algo__solver': 'saga'}
# {'ML_algo__alpha': 35.938136638046274, 'ML_algo__random_state': 10, 'ML_algo__solver': 'saga'}
# {'ML_algo__alpha': 12.91549665014884, 'ML_algo__random_state': 10, 'ML_algo__solver': 'saga'}
# {'ML_algo__alpha': 12.91549665014884, 'ML_algo__random_state': 10, 'ML_algo__solver': 'saga'}
# -----------------------------
# 0.12714753488731623
# 0.15561455727960682
# 0.15196770978031748
# 0.09864234597708987
# 0.11764925868295617
# 0.10104192879148433
# -----------------------------
# r2_score: mean 0.125 +/- 0.022 standard deviation

# %%
from sklearn.linear_model import ElasticNet
#ElasticNet with parameters is used to train the model. Model with best parameters is selected. The mean of r2 score is calculated.

param_grid = {'ML_algo__alpha':[100.0, 35.938136638046274, 12.91549665014884, 4.641588833612779, 1.668100537200059, 0.5994842503189408, 0.21544346900318845, 0.07742636826811278, 0.027825594022071257, 0.01]} 
model3, test_scores3 = MLpipe_KFold(X, y, preprocessor, ElasticNet(), param_grid)
print("-----------------------------")
for m in model3:
    print(m)
print("-----------------------------")
for s in test_scores3:
    print(s)
print("-----------------------------")
print('r2_score:',"mean",np.around(np.mean(test_scores3),3),'+/-',np.around(np.std(test_scores3),3),"standard deviation")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# -----------------------------
# {'ML_algo__alpha': 0.01}
# {'ML_algo__alpha': 0.01}
# {'ML_algo__alpha': 0.01}
# {'ML_algo__alpha': 0.01}
# {'ML_algo__alpha': 0.01}
# {'ML_algo__alpha': 0.01}
# -----------------------------
# 0.12278264979585918
# 0.15583190882370102
# 0.15343660035310114
# 0.09513757878002438
# 0.11603194754692248
# 0.10098957735999226
# -----------------------------
# r2_score: mean 0.124 +/- 0.023 standard deviation

# %%
from sklearn.ensemble import RandomForestRegressor
#RandomForestRegressor with parameters is used to train the model. Model with best parameters is selected. The mean of r2 score is calculated.

param_grid = {'ML_algo__max_depth': [1, 5, 20, 30, 100], 'ML_algo__max_features': [0.4,0.75,1.0], 'ML_algo__random_state': [42], 'ML_algo__n_jobs':[-1]} 
model4, test_scores4 = MLpipe_KFold(X, y, preprocessor, RandomForestRegressor(), param_grid)
print("-----------------------------")
for m in model4:
    print(m)
print("-----------------------------")

for s in test_scores4:
    print(s)
print("-----------------------------")
print('r2_score:',"(mean)",np.around(np.mean(test_scores4),2),'+/-',np.around(np.std(test_scores4),2),"(standard deviation)")
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# -----------------------------
# {'ML_algo__max_depth': 30, 'ML_algo__max_features': 0.4, 'ML_algo__n_jobs': -1, 'ML_algo__random_state': 42}
# {'ML_algo__max_depth': 20, 'ML_algo__max_features': 0.4, 'ML_algo__n_jobs': -1, 'ML_algo__random_state': 42}
# {'ML_algo__max_depth': 20, 'ML_algo__max_features': 0.4, 'ML_algo__n_jobs': -1, 'ML_algo__random_state': 42}
# {'ML_algo__max_depth': 100, 'ML_algo__max_features': 0.4, 'ML_algo__n_jobs': -1, 'ML_algo__random_state': 42}
# {'ML_algo__max_depth': 20, 'ML_algo__max_features': 0.4, 'ML_algo__n_jobs': -1, 'ML_algo__random_state': 42}
# {'ML_algo__max_depth': 20, 'ML_algo__max_features': 0.4, 'ML_algo__n_jobs': -1, 'ML_algo__random_state': 42}
# -----------------------------
# 0.12180160698394749
# 0.2251506324665684
# 0.11239871942423318
# 0.10549305800601516
# 0.11304429565970875
# 0.11195825890412825
# -----------------------------
# test accuracy: (mean) 0.13 +/- 0.04 (standard deviation)

# %%
print(y.isnull().sum)
print(y.shape)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Name: price, Length: 48895, dtype: bool>
# (48895,)

# %%
import xgboost
from sklearn.model_selection import ParameterGrid
import warnings
warnings.filterwarnings("ignore")


random_state = [5, 10, 13, 20, 25]
all_val_scores = []
all_train_scores = []
all_test_scores = []

train_scores_mean = []
val_scores_mean = []
test_scores_mean = []

train_scores_std = []
val_scores_std = []
test_scores_std = []

for i in random_state:#looping through 5 random states
    X_other1, X_test1, y_other1, y_test1 = train_test_split(X, y, test_size = 0.2, random_state=i)    
    kf = KFold(n_splits=5,random_state= i)#split into 5 folds
    for train_index, val_index in kf.split(X_other1,y_other1):
        X_train1 = X_other1.iloc[train_index]
        y_train1 = y_other1.iloc[train_index]
        X_CV = X_other1.iloc[val_index]
        y_CV = y_other1.iloc[val_index]
            
        
    pipeline_fit = Pipeline(steps=[('preprocessor', preprocessor)]) 
        
    X_train1 = pipeline_fit.fit_transform(X_train1)
                        
    X_CV = pipeline_fit.transform(X_CV)

    X_test1 = pipeline_fit.transform(X_test1)
        
    depth_add = []
    sm_add = []
    test_scores = []
    train_scores = []
    val_scores = []
    #loop trough max_depth and subsample parameters and find the best set of parameters.
    max_dep = [1, 2, 3, 6]
    subsample = [0.4, 0.5, 0.66]
    for md in max_dep: 
        for sm in subsample:
            param_grid = {"learning_rate": [0.03],
                              "n_estimators": [10000],
                              "max_depth": [md],
                              "colsample_bytree": [0.9],              
                              "subsample": [sm]}

            XGB = xgboost.XGBRegressor()
            XGB.set_params(**ParameterGrid(param_grid)[0])
            XGB.fit(X_train1,y_train1,early_stopping_rounds = 40,eval_set=[(X_CV, y_CV)], verbose=False)
            y_CV_pred = XGB.predict(X_CV)
            ms1 = r2_score(y_CV,y_CV_pred)#evaluate validation scores
            val_scores.append(ms1)#append validation scores
           
            y_train_pred = XGB.predict(X_train1)
            ms2 = r2_score(y_train1,y_train_pred)#predict train scores
            train_scores.append(ms2)#append tain scores
           
            
            y_test_pred = XGB.predict(X_test1)
            ms3 = r2_score(y_test1, y_test_pred)#predict test scores
            test_scores.append(ms3)#append test scores
            depth_add.append(md)#append depth
            sm_add.append(sm)#append subsample
                                    
            
    #mean of the scores        
    train_scores_mean.append(np.mean(train_scores))
    val_scores_mean.append(np.mean(val_scores))
    test_scores_mean.append(np.mean(test_scores))
    #standard deviation of the scores        
    train_scores_std.append(np.std(train_scores))
    val_scores_std.append(np.std(val_scores))
    test_scores_std.append(np.std(test_scores))
    #store all the scores
    all_val_scores.append(val_scores_mean)
    all_train_scores.append(train_scores_mean)
    all_test_scores.append(test_scores_mean)
            
    print("********************************************")
    #Display the model with best parameters for each random state.
    print("RANDOM STATE: ", i)
    print("Best test scores: ", np.max(test_scores), " ---->   Best max_depth: ", depth_add[np.array(test_scores).argmax()], " Best subsample: ", sm_add[np.array(test_scores).argmax()], "learning_rate: 0.03,  n_estimators: 10000, colsample_bytree: 0.9")
    #write the results into the file
print(" score:(mean)",np.mean(all_test_scores),'+/-',np.std(all_test_scores),"(standard deviation)")
# Out:
# ********************************************
# RANDOM STATE:  5
# Best test scores:  0.11653407264198423  ---->   Best max_depth:  6  Best subsample:  0.66 learning_rate: 0.03,  n_estimators: 10000, colsample_bytree: 0.9
# ********************************************
# RANDOM STATE:  10
# Best test scores:  0.17506150245856944  ---->   Best max_depth:  2  Best subsample:  0.66 learning_rate: 0.03,  n_estimators: 10000, colsample_bytree: 0.9
# ********************************************
# RANDOM STATE:  13
# Best test scores:  0.11013184447449564  ---->   Best max_depth:  6  Best subsample:  0.4 learning_rate: 0.03,  n_estimators: 10000, colsample_bytree: 0.9
# ********************************************
# RANDOM STATE:  20
# Best test scores:  0.1437624178320447  ---->   Best max_depth:  6  Best subsample:  0.5 learning_rate: 0.03,  n_estimators: 10000, colsample_bytree: 0.9
# ********************************************
# RANDOM STATE:  25
# Best test scores:  0.1274750713548104  ---->   Best max_depth:  2  Best subsample:  0.66 learning_rate: 0.03,  n_estimators: 10000, colsample_bytree: 0.9
#  score:(mean) 0.11088781105203344 +/- 0.025592163271840256 (standard deviation)
